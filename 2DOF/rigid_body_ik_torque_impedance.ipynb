# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (8, 4)
plt.rcParams["figure.dpi"] = 120

# %%
# Link geometry
l1, l2 = 0.6, 0.5     # lengths (m)

# Mass properties (choose reasonable values)
m1, m2 = 2.0, 1.5     # masses (kg)
lc1, lc2 = l1/2, l2/2 # COM distances from proximal joint (m)

# Inertias about COM (slender rod approx: I = (1/12) m L^2)
I1 = (1/12) * m1 * l1**2
I2 = (1/12) * m2 * l2**2

g = 9.81

# %%
def fk(q):
    """Forward kinematics: q=[q1,q2] -> p=[x,y]"""
    q1, q2 = q
    x = l1*np.cos(q1) + l2*np.cos(q1+q2)
    y = l1*np.sin(q1) + l2*np.sin(q1+q2)
    return np.array([x, y])

def jacobian(q):
    """Jacobian J(q) mapping qdot -> p_dot"""
    q1, q2 = q
    s1 = np.sin(q1); c1 = np.cos(q1)
    s12 = np.sin(q1+q2); c12 = np.cos(q1+q2)

    J = np.array([
        [-l1*s1 - l2*s12,  -l2*s12],
        [ l1*c1 + l2*c12,   l2*c12]
    ])
    return J

# %%
def ik_dls(p_target, q_init, iters=200, alpha=0.8, lam=1e-2):
    """
    Damped least squares inverse kinematics.
    Returns q that (approximately) reaches p_target.
    """
    q = q_init.copy()
    for _ in range(iters):
        p = fk(q)
        e = p_target - p  # position error

        if np.linalg.norm(e) < 1e-4:
            break

        J = jacobian(q)
        # DLS update: dq = J^T (J J^T + lam^2 I)^{-1} e
        JJt = J @ J.T
        dq = J.T @ np.linalg.solve(JJt + (lam**2)*np.eye(2), e)

        q = q + alpha * dq
    return q

# Test IK
q0 = np.array([0.2, 0.2])
p_star = np.array([0.7, 0.2])  # reachable target
q_sol = ik_dls(p_star, q0)
print("q_sol:", q_sol, "fk(q_sol):", fk(q_sol))
# Out:
# q_sol: [ 1.02702809 -1.70462732] fk(q_sol): [0.69995866 0.1999969 ]

# %%
def M_matrix(q):
    q1, q2 = q
    c2 = np.cos(q2)

    M11 = (I1 + I2
           + m1*lc1**2
           + m2*(l1**2 + lc2**2 + 2*l1*lc2*c2))
    M12 = I2 + m2*(lc2**2 + l1*lc2*c2)
    M22 = I2 + m2*lc2**2

    return np.array([[M11, M12],
                     [M12, M22]])

def C_vector(q, qdot):
    """
    Returns C(q,qdot) qdot as a 2x1 vector.
    """
    q1, q2 = q
    q1d, q2d = qdot
    s2 = np.sin(q2)

    h = m2*l1*lc2*s2

    # Standard 2-link coriolis/centrifugal terms
    C1 = -h*(2*q1d*q2d + q2d**2)
    C2 =  h*(q1d**2)

    return np.array([C1, C2])

def g_vector(q):
    q1, q2 = q
    c1 = np.cos(q1)
    c12 = np.cos(q1+q2)

    G1 = (m1*lc1 + m2*l1)*g*c1 + m2*lc2*g*c12
    G2 = m2*lc2*g*c12

    return np.array([G1, G2])

# %%
def forward_dynamics(q, qdot, tau):
    M = M_matrix(q)
    C = C_vector(q, qdot)
    G = g_vector(q)
    qdd = np.linalg.solve(M, tau - C - G)
    return qdd

def step_euler(q, qdot, tau, dt):
    qdd = forward_dynamics(q, qdot, tau)
    qdot_next = qdot + dt*qdd
    q_next = q + dt*qdot_next
    return q_next, qdot_next

# %%
# Initial joint state
q_start = np.array([0.2, 0.2])
qdot_start = np.array([0.0, 0.0])

# Choose a reachable target and solve IK to get a goal configuration
p_goal = np.array([0.75, 0.15])
q_goal = ik_dls(p_goal, q_start)

print("q_goal:", q_goal, "fk(q_goal):", fk(q_goal))

# Trajectory settings
T = 4.0
dt = 0.002
N = int(T/dt)

t = np.linspace(0, T, N)

# Simple smooth interpolation in joint space
def smoothstep(s):
    return 3*s**2 - 2*s**3

s = smoothstep(t/T)
qd = (1-s)[:,None]*q_start + s[:,None]*q_goal

# desired velocities and accelerations by finite difference
qdd = np.gradient(qd, dt, axis=0)
qddd = np.gradient(qdd, dt, axis=0)
# Out:
# q_goal: [-0.51426439  1.61247136] fk(q_goal): [0.74998955 0.1500596 ]

# %%
# Gains (tune)
Kp = np.diag([120.0, 120.0])
Kd = np.diag([25.0, 25.0])

q = q_start.copy()
qdot = qdot_start.copy()

q_hist = np.zeros((N,2))
tau_hist = np.zeros((N,2))
ee_hist = np.zeros((N,2))

for k in range(N):
    qd_k = qd[k]
    qd_dot = qdd[k]
    qd_ddot = qddd[k]

    e = qd_k - q
    edot = qd_dot - qdot

    M = M_matrix(q)
    C = C_vector(q, qdot)
    G = g_vector(q)

    # Computed torque control
    v = qd_ddot + Kd @ edot + Kp @ e
    tau = M @ v + C + G

    q, qdot = step_euler(q, qdot, tau, dt)

    q_hist[k] = q
    tau_hist[k] = tau
    ee_hist[k] = fk(q)

print("Done.")
# Out:
# Done.

# %%
import os
os.makedirs("outputs1", exist_ok=True)
plt.figure()
plt.plot(t, qd[:,0] , label="q1 desired")
plt.plot(t, q_hist[:,0],"--",linewidth=1,  label="q1 actual")
plt.xlabel("time (s)"); plt.ylabel("rad"); plt.title("Joint 1 tracking (computed torque)")
plt.grid(True); plt.legend(); 
plt.savefig("outputs1/Joint_1_tracking.png", dpi=200)

plt.figure()
plt.plot(t, qd[:,1], label="q2 desired")
plt.plot(t, q_hist[:,1], "--",linewidth=1,  label="q2 actual")
plt.xlabel("time (s)"); plt.ylabel("rad"); plt.title("Joint 2 tracking (computed torque)")
plt.grid(True); plt.legend(); 
plt.savefig("outputs1/Joint_2_tracking.png", dpi=200)

plt.figure()
plt.plot(t, tau_hist[:,0], label="tau1")
plt.plot(t, tau_hist[:,1], label="tau2")
plt.xlabel("time (s)"); plt.ylabel("Nm"); plt.title("Joint torques")
plt.grid(True); plt.legend(); 
plt.savefig("outputs1/Joint_torques.png", dpi=200)

# End-effector path
ee_des = np.array([fk(qd[k]) for k in range(N)])

plt.figure()
plt.plot(ee_des[:,0], ee_des[:,1], "--", label="EE desired path")
plt.plot(ee_hist[:,0], ee_hist[:,1], label="EE actual path")
plt.scatter([p_goal[0]], [p_goal[1]], marker="x", s=80, label="target")
plt.xlabel("x (m)"); plt.ylabel("y (m)"); plt.title("End-effector path")
plt.axis("equal"); plt.grid(True); plt.legend(); 
plt.savefig("outputs1/End_effector.png", dpi=200)

# %%
# Impedance gains
K = np.diag([40.0, 40.0])
D = np.diag([6.0, 6.0])

q = q_goal.copy()         # start at goal
qdot = np.array([0.0, 0.0])

# Apply a "disturbance" torque for a short time to see compliance
disturb_start = int(1.0/dt)
disturb_end   = int(1.2/dt)
disturb_tau   = np.array([3.0, -2.0])

q_imp = np.zeros((N,2))

for k in range(N):
    # Impedance about q_goal
    tau = K @ (q_goal - q) - D @ qdot + g_vector(q)

    # Disturbance
    if disturb_start <= k <= disturb_end:
        tau = tau + disturb_tau

    q, qdot = step_euler(q, qdot, tau, dt)
    q_imp[k] = q

plt.figure()
plt.plot(t, q_imp[:,0], label="q1")
plt.plot(t, q_imp[:,1], label="q2")
#plt.axvspan(disturb_start*dt, disturb_end*dt, alpha=0.2, label="disturbance")
plt.xlabel("time (s)"); plt.ylabel("rad"); plt.title("Impedance control response (compliance)")
plt.grid(True); plt.legend(); 
plt.tight_layout()
plt.savefig("outputs1/ee_path.png", dpi=200)
plt.close()

# %% [markdown]
# ## RL control

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

class TwoLinkReachResidualEnv(gym.Env):
    """
    Residual RL: tau = tau_baseline + delta_tau (RL output).
    Baseline is PD + gravity compensation for stability.
    Observation: [q1,q2,q1dot,q2dot, ex, ey]
    Action: delta_tau (bounded)
    """
    metadata = {"render_modes": []}

    def __init__(self, dt=0.01, max_steps=200, tau_max=12.0, delta_max=4.0, seed=0):
        super().__init__()
        self.dt = dt
        self.max_steps = max_steps
        self.tau_max = tau_max
        self.delta_max = delta_max
        self.rng = np.random.default_rng(seed)

        self.action_space = spaces.Box(
            low=-self.delta_max, high=self.delta_max, shape=(2,), dtype=np.float32
        )

        high = np.array([np.pi, np.pi, 10.0, 10.0, 2.0, 2.0], dtype=np.float32)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        # Baseline gains (stable but not perfect)
        self.Kp = np.array([60.0, 60.0])
        self.Kd = np.array([10.0, 10.0])

        self.q = None
        self.qdot = None
        self.target = None
        self.q_goal = None
        self.step_count = 0
        self.prev_dist = None

    def _sample_target(self):
        r_min = 0.35
        r_max = (l1 + l2) - 0.08
        r = self.rng.uniform(r_min, r_max)
        theta = self.rng.uniform(-0.9, 0.9)
        return np.array([r*np.cos(theta), r*np.sin(theta)])

    def _get_obs(self):
        ee = fk(self.q)
        e = ee - self.target
        return np.array([self.q[0], self.q[1], self.qdot[0], self.qdot[1], e[0], e[1]], dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.step_count = 0

        self.q = np.array([0.2, 0.2], dtype=float) + self.rng.normal(0, 0.05, size=2)
        self.qdot = np.zeros(2, dtype=float)

        self.target = self._sample_target()
        self.q_goal = ik_dls(self.target, self.q.copy(), iters=200, alpha=0.8, lam=1e-2)

        self.prev_dist = np.linalg.norm(fk(self.q) - self.target)

        return self._get_obs(), {"target": self.target.copy()}

    def step(self, action):
        self.step_count += 1

        # Baseline torque: PD to q_goal + gravity compensation
        e = self.q_goal - self.q
        edot = -self.qdot
        tau_base = self.Kp * e + self.Kd * edot + g_vector(self.q)

        # RL residual
        delta = np.clip(action, -self.delta_max, self.delta_max).astype(float)
        tau = tau_base + delta
        tau = np.clip(tau, -self.tau_max, self.tau_max)

        # simulate
        self.q, self.qdot = step_euler(self.q, self.qdot, tau, self.dt)

        ee = fk(self.q)
        dist = np.linalg.norm(ee - self.target)

        # Reward shaping:
        # 1) negative distance
        # 2) progress bonus (getting closer)
        # 3) small penalties for velocity + residual size
        progress = self.prev_dist - dist
        self.prev_dist = dist

        reward = -dist + 2.0*progress
        reward += -0.01*np.linalg.norm(self.qdot)
        reward += -0.01*np.linalg.norm(delta)

        terminated = False
        if dist < 0.03:
            reward += 5.0
            terminated = True

        truncated = (self.step_count >= self.max_steps)
        return self._get_obs(), reward, terminated, truncated, {"dist": dist}

# %%
from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env

env = make_vec_env(lambda: TwoLinkReachResidualEnv(dt=0.01, max_steps=200, seed=0), n_envs=4)

model = SAC(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=3e-4,
    batch_size=256,
    gamma=0.99,
    tau=0.005,
)

model.learn(total_timesteps=100_000)  # start here; usually enough for clean demo
model.save("sac_2link_reach_residual")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | -233     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 267      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | -1.55    |
# |    critic_loss     | 0.0691   |
# |    ent_coef        | 0.935    |
# |    ent_coef_loss   | -0.224   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 224      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | -266     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 252      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -1.39    |
# |    critic_loss     | 0.0578   |
# |    ent_coef        | 0.868    |
# |    ent_coef_loss   | -0.477   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 474      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | -248     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 248      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | -1.24    |
# |    critic_loss     | 0.0423   |
# |    ent_coef        | 0.805    |
# |    ent_coef_loss   | -0.729   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 724      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | -220     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 244      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -1.07    |
# |    critic_loss     | 0.0755   |
# |    ent_coef        | 0.747    |
# |    ent_coef_loss   | -0.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 974      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 217      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 243      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -0.66    |
# |    critic_loss     | 0.0469   |
# |    ent_coef        | 0.693    |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1224     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | -240     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 244      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -0.384   |
# |    critic_loss     | 0.0512   |
# |    ent_coef        | 0.643    |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1474     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -257     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 241      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | 0.863    |
# |    critic_loss     | 0.0496   |
# |    ent_coef        | 0.596    |
# |    ent_coef_loss   | -1.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1724     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | -259     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 239      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 1.14     |
# |    critic_loss     | 0.037    |
# |    ent_coef        | 0.553    |
# |    ent_coef_loss   | -2.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1974     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | -257     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 239      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | 1.75     |
# |    critic_loss     | 0.0464   |
# |    ent_coef        | 0.513    |
# |    ent_coef_loss   | -2.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2224     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | -262     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 238      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 2.6      |
# |    critic_loss     | 0.0532   |
# |    ent_coef        | 0.476    |
# |    ent_coef_loss   | -2.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2474     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | -262     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 238      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | 3.21     |
# |    critic_loss     | 0.0663   |
# |    ent_coef        | 0.442    |
# |    ent_coef_loss   | -2.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2724     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | -262     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 237      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | 3.85     |
# |    critic_loss     | 0.0758   |
# |    ent_coef        | 0.41     |
# |    ent_coef_loss   | -2.97    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2974     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | -260     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 237      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 12128    |
# | train/             |          |
# |    actor_loss      | 3.88     |
# |    critic_loss     | 0.0932   |
# |    ent_coef        | 0.406    |
# |    ent_coef_loss   | -3.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3006     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | -258     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 237      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 13128    |
# | train/             |          |
# |    actor_loss      | 4.32     |
# |    critic_loss     | 0.0929   |
# |    ent_coef        | 0.377    |
# |    ent_coef_loss   | -3.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3256     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | -255     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 238      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 14116    |
# | train/             |          |
# |    actor_loss      | 4.48     |
# |    critic_loss     | 0.0803   |
# |    ent_coef        | 0.35     |
# |    ent_coef_loss   | -3.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3503     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 235      |
# |    ep_rew_mean     | -254     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 239      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 15116    |
# | train/             |          |
# |    actor_loss      | 6.16     |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.325    |
# |    ent_coef_loss   | -3.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3753     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | -253     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 240      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 16116    |
# | train/             |          |
# |    actor_loss      | 6.59     |
# |    critic_loss     | 0.13     |
# |    ent_coef        | 0.302    |
# |    ent_coef_loss   | -3.83    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4003     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | -255     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 240      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 17116    |
# | train/             |          |
# |    actor_loss      | 7.91     |
# |    critic_loss     | 0.102    |
# |    ent_coef        | 0.281    |
# |    ent_coef_loss   | -4.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4253     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | -255     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 241      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 18116    |
# | train/             |          |
# |    actor_loss      | 9.23     |
# |    critic_loss     | 0.112    |
# |    ent_coef        | 0.261    |
# |    ent_coef_loss   | -4.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4503     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | -251     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 242      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 18984    |
# | train/             |          |
# |    actor_loss      | 9.38     |
# |    critic_loss     | 0.224    |
# |    ent_coef        | 0.245    |
# |    ent_coef_loss   | -4.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4720     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | -252     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 243      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 19984    |
# | train/             |          |
# |    actor_loss      | 12.4     |
# |    critic_loss     | 0.153    |
# |    ent_coef        | 0.228    |
# |    ent_coef_loss   | -4.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4970     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | -253     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 243      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 20972    |
# | train/             |          |
# |    actor_loss      | 11.6     |
# |    critic_loss     | 0.198    |
# |    ent_coef        | 0.212    |
# |    ent_coef_loss   | -4.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5217     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 235      |
# |    ep_rew_mean     | -256     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 243      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 21972    |
# | train/             |          |
# |    actor_loss      | 12.9     |
# |    critic_loss     | 0.289    |
# |    ent_coef        | 0.198    |
# |    ent_coef_loss   | -4.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5467     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 235      |
# |    ep_rew_mean     | -259     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 244      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 22972    |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.421    |
# |    ent_coef        | 0.184    |
# |    ent_coef_loss   | -4.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5717     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | -261     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 244      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 23972    |
# | train/             |          |
# |    actor_loss      | 16.6     |
# |    critic_loss     | 0.318    |
# |    ent_coef        | 0.172    |
# |    ent_coef_loss   | -5.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5967     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 235      |
# |    ep_rew_mean     | -263     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 245      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 24820    |
# | train/             |          |
# |    actor_loss      | 16.9     |
# |    critic_loss     | 0.356    |
# |    ent_coef        | 0.162    |
# |    ent_coef_loss   | -4.93    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6179     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 235      |
# |    ep_rew_mean     | -261     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 245      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 25820    |
# | train/             |          |
# |    actor_loss      | 19       |
# |    critic_loss     | 0.393    |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -5.37    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6429     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | -260     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 245      |
# |    time_elapsed    | 109      |
# |    total_timesteps | 26820    |
# | train/             |          |
# |    actor_loss      | 19.2     |
# |    critic_loss     | 1.59     |
# |    ent_coef        | 0.141    |
# |    ent_coef_loss   | -4.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6679     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | -256     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 245      |
# |    time_elapsed    | 110      |
# |    total_timesteps | 27168    |
# | train/             |          |
# |    actor_loss      | 18.4     |
# |    critic_loss     | 0.884    |
# |    ent_coef        | 0.138    |
# |    ent_coef_loss   | -5.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6766     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | -251     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 245      |
# |    time_elapsed    | 112      |
# |    total_timesteps | 27704    |
# | train/             |          |
# |    actor_loss      | 20.2     |
# |    critic_loss     | 0.335    |
# |    ent_coef        | 0.133    |
# |    ent_coef_loss   | -4.97    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6900     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | -247     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 246      |
# |    time_elapsed    | 115      |
# |    total_timesteps | 28376    |
# | train/             |          |
# |    actor_loss      | 18.9     |
# |    critic_loss     | 0.978    |
# |    ent_coef        | 0.127    |
# |    ent_coef_loss   | -5.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7068     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | -240     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 246      |
# |    time_elapsed    | 118      |
# |    total_timesteps | 29168    |
# | train/             |          |
# |    actor_loss      | 19.1     |
# |    critic_loss     | 0.539    |
# |    ent_coef        | 0.121    |
# |    ent_coef_loss   | -4.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7266     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -239     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 246      |
# |    time_elapsed    | 122      |
# |    total_timesteps | 30168    |
# | train/             |          |
# |    actor_loss      | 20.2     |
# |    critic_loss     | 0.399    |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | -5.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7516     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -238     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 246      |
# |    time_elapsed    | 126      |
# |    total_timesteps | 31168    |
# | train/             |          |
# |    actor_loss      | 23.5     |
# |    critic_loss     | 0.54     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -4.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7766     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 246      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 32168    |
# | train/             |          |
# |    actor_loss      | 24       |
# |    critic_loss     | 0.893    |
# |    ent_coef        | 0.0992   |
# |    ent_coef_loss   | -5.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8016     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | -232     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 247      |
# |    time_elapsed    | 133      |
# |    total_timesteps | 33064    |
# | train/             |          |
# |    actor_loss      | 23       |
# |    critic_loss     | 0.826    |
# |    ent_coef        | 0.0937   |
# |    ent_coef_loss   | -4.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8240     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 247      |
# |    time_elapsed    | 137      |
# |    total_timesteps | 34064    |
# | train/             |          |
# |    actor_loss      | 23.7     |
# |    critic_loss     | 0.74     |
# |    ent_coef        | 0.088    |
# |    ent_coef_loss   | -4.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8490     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 247      |
# |    time_elapsed    | 140      |
# |    total_timesteps | 34864    |
# | train/             |          |
# |    actor_loss      | 25.2     |
# |    critic_loss     | 0.553    |
# |    ent_coef        | 0.0837   |
# |    ent_coef_loss   | -4.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8690     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 247      |
# |    time_elapsed    | 144      |
# |    total_timesteps | 35848    |
# | train/             |          |
# |    actor_loss      | 26.8     |
# |    critic_loss     | 0.654    |
# |    ent_coef        | 0.0788   |
# |    ent_coef_loss   | -4.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8936     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 220      |
# |    ep_rew_mean     | -227     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 247      |
# |    time_elapsed    | 147      |
# |    total_timesteps | 36524    |
# | train/             |          |
# |    actor_loss      | 27.5     |
# |    critic_loss     | 0.528    |
# |    ent_coef        | 0.0757   |
# |    ent_coef_loss   | -4.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9105     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 220      |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 248      |
# |    time_elapsed    | 151      |
# |    total_timesteps | 37524    |
# | train/             |          |
# |    actor_loss      | 28.7     |
# |    critic_loss     | 0.871    |
# |    ent_coef        | 0.0715   |
# |    ent_coef_loss   | -3.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9355     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | -227     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 248      |
# |    time_elapsed    | 152      |
# |    total_timesteps | 37940    |
# | train/             |          |
# |    actor_loss      | 30.4     |
# |    critic_loss     | 0.799    |
# |    ent_coef        | 0.0698   |
# |    ent_coef_loss   | -3.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9459     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 248      |
# |    time_elapsed    | 156      |
# |    total_timesteps | 38940    |
# | train/             |          |
# |    actor_loss      | 30.1     |
# |    critic_loss     | 0.672    |
# |    ent_coef        | 0.0659   |
# |    ent_coef_loss   | -3.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9709     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 248      |
# |    time_elapsed    | 160      |
# |    total_timesteps | 39776    |
# | train/             |          |
# |    actor_loss      | 30.8     |
# |    critic_loss     | 0.742    |
# |    ent_coef        | 0.0629   |
# |    ent_coef_loss   | -4.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9918     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 248      |
# |    time_elapsed    | 160      |
# |    total_timesteps | 39992    |
# | train/             |          |
# |    actor_loss      | 30.7     |
# |    critic_loss     | 2.23     |
# |    ent_coef        | 0.0621   |
# |    ent_coef_loss   | -3.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9972     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 248      |
# |    time_elapsed    | 163      |
# |    total_timesteps | 40536    |
# | train/             |          |
# |    actor_loss      | 31.3     |
# |    critic_loss     | 0.934    |
# |    ent_coef        | 0.0604   |
# |    ent_coef_loss   | -3.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10108    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 248      |
# |    time_elapsed    | 165      |
# |    total_timesteps | 41032    |
# | train/             |          |
# |    actor_loss      | 34.1     |
# |    critic_loss     | 2.43     |
# |    ent_coef        | 0.0587   |
# |    ent_coef_loss   | -3.54    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10232    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 248      |
# |    time_elapsed    | 167      |
# |    total_timesteps | 41536    |
# | train/             |          |
# |    actor_loss      | 32.8     |
# |    critic_loss     | 0.892    |
# |    ent_coef        | 0.057    |
# |    ent_coef_loss   | -3.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10358    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 248      |
# |    time_elapsed    | 170      |
# |    total_timesteps | 42536    |
# | train/             |          |
# |    actor_loss      | 34.7     |
# |    critic_loss     | 0.9      |
# |    ent_coef        | 0.0541   |
# |    ent_coef_loss   | -2.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10608    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 249      |
# |    time_elapsed    | 174      |
# |    total_timesteps | 43536    |
# | train/             |          |
# |    actor_loss      | 33.2     |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.0513   |
# |    ent_coef_loss   | -2.68    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10858    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -188     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 249      |
# |    time_elapsed    | 178      |
# |    total_timesteps | 44536    |
# | train/             |          |
# |    actor_loss      | 34       |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.0489   |
# |    ent_coef_loss   | -3.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11108    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -186     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 249      |
# |    time_elapsed    | 182      |
# |    total_timesteps | 45536    |
# | train/             |          |
# |    actor_loss      | 34       |
# |    critic_loss     | 0.843    |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | -2.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11358    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | -183     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 249      |
# |    time_elapsed    | 186      |
# |    total_timesteps | 46536    |
# | train/             |          |
# |    actor_loss      | 34.4     |
# |    critic_loss     | 0.88     |
# |    ent_coef        | 0.0445   |
# |    ent_coef_loss   | -2.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11608    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | -187     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 249      |
# |    time_elapsed    | 190      |
# |    total_timesteps | 47536    |
# | train/             |          |
# |    actor_loss      | 35.9     |
# |    critic_loss     | 3.4      |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | -1.54    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11858    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 249      |
# |    time_elapsed    | 194      |
# |    total_timesteps | 48536    |
# | train/             |          |
# |    actor_loss      | 34.7     |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | -2.13    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12108    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 250      |
# |    time_elapsed    | 198      |
# |    total_timesteps | 49536    |
# | train/             |          |
# |    actor_loss      | 36.3     |
# |    critic_loss     | 0.791    |
# |    ent_coef        | 0.0393   |
# |    ent_coef_loss   | -2.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12358    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | -188     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 250      |
# |    time_elapsed    | 200      |
# |    total_timesteps | 50200    |
# | train/             |          |
# |    actor_loss      | 37.9     |
# |    critic_loss     | 1.43     |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | -0.439   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12524    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | -183     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 250      |
# |    time_elapsed    | 204      |
# |    total_timesteps | 51080    |
# | train/             |          |
# |    actor_loss      | 36.1     |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.0367   |
# |    ent_coef_loss   | -0.183   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12744    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 250      |
# |    time_elapsed    | 205      |
# |    total_timesteps | 51548    |
# | train/             |          |
# |    actor_loss      | 38.2     |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | -1.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12861    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | -175     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 250      |
# |    time_elapsed    | 210      |
# |    total_timesteps | 52548    |
# | train/             |          |
# |    actor_loss      | 37.6     |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.0351   |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13111    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | -176     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 249      |
# |    time_elapsed    | 214      |
# |    total_timesteps | 53548    |
# | train/             |          |
# |    actor_loss      | 37.8     |
# |    critic_loss     | 0.864    |
# |    ent_coef        | 0.0341   |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13361    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | -174     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 249      |
# |    time_elapsed    | 218      |
# |    total_timesteps | 54548    |
# | train/             |          |
# |    actor_loss      | 38.9     |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.0331   |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13611    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | -173     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 250      |
# |    time_elapsed    | 222      |
# |    total_timesteps | 55548    |
# | train/             |          |
# |    actor_loss      | 39.9     |
# |    critic_loss     | 5.8      |
# |    ent_coef        | 0.0325   |
# |    ent_coef_loss   | -0.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13861    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | -168     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 250      |
# |    time_elapsed    | 225      |
# |    total_timesteps | 56548    |
# | train/             |          |
# |    actor_loss      | 39.8     |
# |    critic_loss     | 2.67     |
# |    ent_coef        | 0.0317   |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14111    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | -168     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 250      |
# |    time_elapsed    | 229      |
# |    total_timesteps | 57548    |
# | train/             |          |
# |    actor_loss      | 39.8     |
# |    critic_loss     | 0.743    |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | 0.564    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14361    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | -160     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 250      |
# |    time_elapsed    | 233      |
# |    total_timesteps | 58416    |
# | train/             |          |
# |    actor_loss      | 38.4     |
# |    critic_loss     | 0.999    |
# |    ent_coef        | 0.0313   |
# |    ent_coef_loss   | 0.131    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14578    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | -158     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 250      |
# |    time_elapsed    | 235      |
# |    total_timesteps | 59096    |
# | train/             |          |
# |    actor_loss      | 41.5     |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.0312   |
# |    ent_coef_loss   | -0.918   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14748    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 210      |
# |    ep_rew_mean     | -153     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 250      |
# |    time_elapsed    | 239      |
# |    total_timesteps | 60056    |
# | train/             |          |
# |    actor_loss      | 40.3     |
# |    critic_loss     | 1.25     |
# |    ent_coef        | 0.0309   |
# |    ent_coef_loss   | 0.578    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14988    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | -153     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 250      |
# |    time_elapsed    | 243      |
# |    total_timesteps | 61056    |
# | train/             |          |
# |    actor_loss      | 43.7     |
# |    critic_loss     | 1.78     |
# |    ent_coef        | 0.0308   |
# |    ent_coef_loss   | 0.903    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15238    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | -157     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 250      |
# |    time_elapsed    | 247      |
# |    total_timesteps | 62056    |
# | train/             |          |
# |    actor_loss      | 40.8     |
# |    critic_loss     | 9        |
# |    ent_coef        | 0.0307   |
# |    ent_coef_loss   | 2.41     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15488    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | -161     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 250      |
# |    time_elapsed    | 249      |
# |    total_timesteps | 62680    |
# | train/             |          |
# |    actor_loss      | 41.3     |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.0305   |
# |    ent_coef_loss   | 0.404    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15644    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -161     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 250      |
# |    time_elapsed    | 253      |
# |    total_timesteps | 63592    |
# | train/             |          |
# |    actor_loss      | 40.4     |
# |    critic_loss     | 0.95     |
# |    ent_coef        | 0.0307   |
# |    ent_coef_loss   | -0.855   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15872    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | -162     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 251      |
# |    time_elapsed    | 257      |
# |    total_timesteps | 64540    |
# | train/             |          |
# |    actor_loss      | 41.6     |
# |    critic_loss     | 4.02     |
# |    ent_coef        | 0.0312   |
# |    ent_coef_loss   | 0.439    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16109    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -159     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 251      |
# |    time_elapsed    | 258      |
# |    total_timesteps | 65056    |
# | train/             |          |
# |    actor_loss      | 40.9     |
# |    critic_loss     | 1.53     |
# |    ent_coef        | 0.0317   |
# |    ent_coef_loss   | -0.476   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16238    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -155     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 251      |
# |    time_elapsed    | 262      |
# |    total_timesteps | 66056    |
# | train/             |          |
# |    actor_loss      | 43.6     |
# |    critic_loss     | 1.31     |
# |    ent_coef        | 0.032    |
# |    ent_coef_loss   | 0.422    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16488    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -155     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 251      |
# |    time_elapsed    | 266      |
# |    total_timesteps | 67056    |
# | train/             |          |
# |    actor_loss      | 44.9     |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.0322   |
# |    ent_coef_loss   | 0.299    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16738    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -155     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 251      |
# |    time_elapsed    | 270      |
# |    total_timesteps | 68056    |
# | train/             |          |
# |    actor_loss      | 43.5     |
# |    critic_loss     | 1.36     |
# |    ent_coef        | 0.0328   |
# |    ent_coef_loss   | 0.0335   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16988    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -157     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 251      |
# |    time_elapsed    | 274      |
# |    total_timesteps | 69056    |
# | train/             |          |
# |    actor_loss      | 42.1     |
# |    critic_loss     | 1.81     |
# |    ent_coef        | 0.0334   |
# |    ent_coef_loss   | 0.53     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17238    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -156     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 251      |
# |    time_elapsed    | 278      |
# |    total_timesteps | 70056    |
# | train/             |          |
# |    actor_loss      | 45.6     |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.0332   |
# |    ent_coef_loss   | 0.368    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17488    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -153     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 251      |
# |    time_elapsed    | 282      |
# |    total_timesteps | 71056    |
# | train/             |          |
# |    actor_loss      | 44.2     |
# |    critic_loss     | 1.56     |
# |    ent_coef        | 0.0335   |
# |    ent_coef_loss   | 0.528    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17738    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -148     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 251      |
# |    time_elapsed    | 286      |
# |    total_timesteps | 72056    |
# | train/             |          |
# |    actor_loss      | 43.7     |
# |    critic_loss     | 10.2     |
# |    ent_coef        | 0.0335   |
# |    ent_coef_loss   | -0.547   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17988    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | -147     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 251      |
# |    time_elapsed    | 290      |
# |    total_timesteps | 73056    |
# | train/             |          |
# |    actor_loss      | 45.5     |
# |    critic_loss     | 1.89     |
# |    ent_coef        | 0.0341   |
# |    ent_coef_loss   | 0.843    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18238    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | -146     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 251      |
# |    time_elapsed    | 294      |
# |    total_timesteps | 74056    |
# | train/             |          |
# |    actor_loss      | 45.6     |
# |    critic_loss     | 1.87     |
# |    ent_coef        | 0.0337   |
# |    ent_coef_loss   | -0.768   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18488    |
# ---------------------------------
# ...
# |    fps             | 248      |
# |    time_elapsed    | 725      |
# |    total_timesteps | 180388   |
# | train/             |          |
# |    actor_loss      | 47.2     |
# |    critic_loss     | 1.12     |
# |    ent_coef        | 0.0366   |
# |    ent_coef_loss   | -0.271   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45071    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | -76.6    |
# | time/              |          |
# |    episodes        | 844      |
# |    fps             | 248      |
# |    time_elapsed    | 727      |
# |    total_timesteps | 180708   |
# | train/             |          |
# |    actor_loss      | 47.4     |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.0363   |
# |    ent_coef_loss   | 0.221    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45151    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | -77.1    |
# | time/              |          |
# |    episodes        | 848      |
# |    fps             | 248      |
# |    time_elapsed    | 731      |
# |    total_timesteps | 181708   |
# | train/             |          |
# |    actor_loss      | 45.8     |
# |    critic_loss     | 6.5      |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | 0.634    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45401    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -78      |
# | time/              |          |
# |    episodes        | 852      |
# |    fps             | 248      |
# |    time_elapsed    | 734      |
# |    total_timesteps | 182708   |
# | train/             |          |
# |    actor_loss      | 48.2     |
# |    critic_loss     | 0.874    |
# |    ent_coef        | 0.0363   |
# |    ent_coef_loss   | 1.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45651    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -78.6    |
# | time/              |          |
# |    episodes        | 856      |
# |    fps             | 248      |
# |    time_elapsed    | 737      |
# |    total_timesteps | 183276   |
# | train/             |          |
# |    actor_loss      | 44.6     |
# |    critic_loss     | 2.16     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | 0.284    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45793    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -78.7    |
# | time/              |          |
# |    episodes        | 860      |
# |    fps             | 248      |
# |    time_elapsed    | 739      |
# |    total_timesteps | 183984   |
# | train/             |          |
# |    actor_loss      | 50.7     |
# |    critic_loss     | 1.39     |
# |    ent_coef        | 0.0368   |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45970    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -80.2    |
# | time/              |          |
# |    episodes        | 864      |
# |    fps             | 248      |
# |    time_elapsed    | 743      |
# |    total_timesteps | 184900   |
# | train/             |          |
# |    actor_loss      | 46       |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.0369   |
# |    ent_coef_loss   | 0.786    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | -81.5    |
# | time/              |          |
# |    episodes        | 868      |
# |    fps             | 248      |
# |    time_elapsed    | 746      |
# |    total_timesteps | 185708   |
# | train/             |          |
# |    actor_loss      | 45       |
# |    critic_loss     | 0.774    |
# |    ent_coef        | 0.0372   |
# |    ent_coef_loss   | -0.508   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46401    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | -82.3    |
# | time/              |          |
# |    episodes        | 872      |
# |    fps             | 248      |
# |    time_elapsed    | 749      |
# |    total_timesteps | 186600   |
# | train/             |          |
# |    actor_loss      | 46.5     |
# |    critic_loss     | 0.924    |
# |    ent_coef        | 0.0367   |
# |    ent_coef_loss   | -0.534   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46624    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -81.6    |
# | time/              |          |
# |    episodes        | 876      |
# |    fps             | 248      |
# |    time_elapsed    | 752      |
# |    total_timesteps | 187268   |
# | train/             |          |
# |    actor_loss      | 48       |
# |    critic_loss     | 1.44     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | -0.118   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46791    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | -79.7    |
# | time/              |          |
# |    episodes        | 880      |
# |    fps             | 248      |
# |    time_elapsed    | 755      |
# |    total_timesteps | 188008   |
# | train/             |          |
# |    actor_loss      | 48.1     |
# |    critic_loss     | 1.21     |
# |    ent_coef        | 0.0361   |
# |    ent_coef_loss   | -0.818   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46976    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | -79.1    |
# | time/              |          |
# |    episodes        | 884      |
# |    fps             | 248      |
# |    time_elapsed    | 757      |
# |    total_timesteps | 188536   |
# | train/             |          |
# |    actor_loss      | 47.8     |
# |    critic_loss     | 19       |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | -0.175   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47108    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | -77.1    |
# | time/              |          |
# |    episodes        | 888      |
# |    fps             | 248      |
# |    time_elapsed    | 760      |
# |    total_timesteps | 189312   |
# | train/             |          |
# |    actor_loss      | 47.1     |
# |    critic_loss     | 1.37     |
# |    ent_coef        | 0.0366   |
# |    ent_coef_loss   | -0.13    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47302    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | -78.5    |
# | time/              |          |
# |    episodes        | 892      |
# |    fps             | 248      |
# |    time_elapsed    | 762      |
# |    total_timesteps | 189980   |
# | train/             |          |
# |    actor_loss      | 48.6     |
# |    critic_loss     | 3.92     |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | 0.751    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | -80.1    |
# | time/              |          |
# |    episodes        | 896      |
# |    fps             | 249      |
# |    time_elapsed    | 766      |
# |    total_timesteps | 190980   |
# | train/             |          |
# |    actor_loss      | 45.3     |
# |    critic_loss     | 1.06     |
# |    ent_coef        | 0.0369   |
# |    ent_coef_loss   | 0.0372   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47719    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | -80.6    |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 249      |
# |    time_elapsed    | 768      |
# |    total_timesteps | 191464   |
# | train/             |          |
# |    actor_loss      | 48.3     |
# |    critic_loss     | 1.74     |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | 0.738    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47840    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | -81.4    |
# | time/              |          |
# |    episodes        | 904      |
# |    fps             | 249      |
# |    time_elapsed    | 772      |
# |    total_timesteps | 192464   |
# | train/             |          |
# |    actor_loss      | 46.6     |
# |    critic_loss     | 0.912    |
# |    ent_coef        | 0.037    |
# |    ent_coef_loss   | 0.383    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48090    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | -80.7    |
# | time/              |          |
# |    episodes        | 908      |
# |    fps             | 249      |
# |    time_elapsed    | 775      |
# |    total_timesteps | 193076   |
# | train/             |          |
# |    actor_loss      | 45.9     |
# |    critic_loss     | 0.873    |
# |    ent_coef        | 0.0373   |
# |    ent_coef_loss   | -0.944   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48243    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | -79.6    |
# | time/              |          |
# |    episodes        | 912      |
# |    fps             | 249      |
# |    time_elapsed    | 777      |
# |    total_timesteps | 193760   |
# | train/             |          |
# |    actor_loss      | 45.1     |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48414    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | -77.4    |
# | time/              |          |
# |    episodes        | 916      |
# |    fps             | 249      |
# |    time_elapsed    | 781      |
# |    total_timesteps | 194760   |
# | train/             |          |
# |    actor_loss      | 46.6     |
# |    critic_loss     | 2.67     |
# |    ent_coef        | 0.0364   |
# |    ent_coef_loss   | -0.321   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48664    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | -77.9    |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 249      |
# |    time_elapsed    | 783      |
# |    total_timesteps | 195384   |
# | train/             |          |
# |    actor_loss      | 46.9     |
# |    critic_loss     | 0.818    |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | 0.119    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48820    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | -76.3    |
# | time/              |          |
# |    episodes        | 924      |
# |    fps             | 249      |
# |    time_elapsed    | 786      |
# |    total_timesteps | 195940   |
# | train/             |          |
# |    actor_loss      | 47.7     |
# |    critic_loss     | 1.43     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | 0.518    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48959    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 185      |
# |    ep_rew_mean     | -76.3    |
# | time/              |          |
# |    episodes        | 928      |
# |    fps             | 249      |
# |    time_elapsed    | 789      |
# |    total_timesteps | 196784   |
# | train/             |          |
# |    actor_loss      | 48.4     |
# |    critic_loss     | 0.862    |
# |    ent_coef        | 0.0353   |
# |    ent_coef_loss   | 0.243    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49170    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 182      |
# |    ep_rew_mean     | -75.9    |
# | time/              |          |
# |    episodes        | 932      |
# |    fps             | 249      |
# |    time_elapsed    | 791      |
# |    total_timesteps | 197384   |
# | train/             |          |
# |    actor_loss      | 46.8     |
# |    critic_loss     | 1.22     |
# |    ent_coef        | 0.0355   |
# |    ent_coef_loss   | 0.204    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49320    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 183      |
# |    ep_rew_mean     | -76.4    |
# | time/              |          |
# |    episodes        | 936      |
# |    fps             | 249      |
# |    time_elapsed    | 793      |
# |    total_timesteps | 197948   |
# | train/             |          |
# |    actor_loss      | 46.9     |
# |    critic_loss     | 0.931    |
# |    ent_coef        | 0.0355   |
# |    ent_coef_loss   | 0.481    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49461    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 184      |
# |    ep_rew_mean     | -76.5    |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 249      |
# |    time_elapsed    | 797      |
# |    total_timesteps | 198848   |
# | train/             |          |
# |    actor_loss      | 48.5     |
# |    critic_loss     | 0.83     |
# |    ent_coef        | 0.0355   |
# |    ent_coef_loss   | -0.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49686    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 186      |
# |    ep_rew_mean     | -77.1    |
# | time/              |          |
# |    episodes        | 944      |
# |    fps             | 249      |
# |    time_elapsed    | 798      |
# |    total_timesteps | 199284   |
# | train/             |          |
# |    actor_loss      | 46.5     |
# |    critic_loss     | 0.783    |
# |    ent_coef        | 0.0354   |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49795    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 179      |
# |    ep_rew_mean     | -74.4    |
# | time/              |          |
# |    episodes        | 948      |
# |    fps             | 249      |
# |    time_elapsed    | 800      |
# |    total_timesteps | 199728   |
# | train/             |          |
# |    actor_loss      | 47.1     |
# |    critic_loss     | 5.87     |
# |    ent_coef        | 0.0356   |
# |    ent_coef_loss   | -0.702   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49906    |
# ---------------------------------

# %%
test_env = TwoLinkReachResidualEnv(dt=0.01, max_steps=200, seed=42)
obs, info = test_env.reset()

ees, dists = [], []
for _ in range(200):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = test_env.step(action)
    ees.append(fk(test_env.q))
    dists.append(info["dist"])
    if terminated or truncated:
        break

ees = np.array(ees)

plt.figure()
plt.plot(dists)
plt.xlabel("Step"); plt.ylabel("Distance (m)")
plt.title("Residual RL reaching (distance over time)")
plt.grid(True); plt.show()

plt.figure()
plt.plot(ees[:,0], ees[:,1], label="EE path")
plt.scatter(test_env.target[0], test_env.target[1], marker="x", s=120, label="Target")
plt.axis("equal"); plt.grid(True); plt.legend()
plt.title("End-effector path (Residual RL policy)")
plt.show()
